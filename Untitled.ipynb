# %% [markdown]
# # Face_Recongnition_Demo

# %%
from face_brain import Face_brain
from matplotlib import pylab as plt
import numpy as np
import cv2

# %matplotlib inline
# Out:
# /Users/zhangshulin_work/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
face_brain = Face_brain()
# Out:
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Restoring parameters from ./pretrain_inception_resnet_v1/model-20170512-110547.ckpt

# %%
zhao = face_brain.read_images(['./赵丽颖1.jpg', './赵丽颖2.jpg', './赵丽颖3.jpg'])
print(zhao.shape)
plt.imshow(zhao[1])
zhao_encode = face_brain.encode_faces(zhao)
zhao_encode.shape
# Out:
# (3,)
# image.shape: (451, 345, 3)
# image.shape: (1022, 810, 3)
# image.shape: (258, 284, 3)
# (3, 128)

# %%
ao = face_brain.read_images(['./ao1.jpg', './ao2.jpg', './ao3.jpg', './ao4.jpg'])
print(ao.shape)
plt.imshow(ao[1])
ao_encode = face_brain.encode_faces(ao)
ao.shape
# Out:
# (4,)
# image.shape: (303, 234, 3)
# image.shape: (152, 130, 3)
# image.shape: (180, 147, 3)
# image.shape: (236, 189, 3)
# (4,)

# %%
face_brain.compare_faces(ao_encode[0], zhao_encode)
# Out:
# array([1.4214714, 1.5248053, 1.4921625], dtype=float32)

# %%
face_brain.compare_faces(ao_encode[0], ao_encode)
# Out:
# array([0.        , 0.5551017 , 0.5488565 , 0.49780902], dtype=float32)

# %%
def img_to_encoding(path, ignore):
    img = face_brain.read_image(path)
    img = face_brain.encode_faces(img)
    return img

FRmodel = None

# %%
database = {}
database["danielle"] = img_to_encoding("images/danielle.png", FRmodel)
database["younes"] = img_to_encoding("images/younes.jpg", FRmodel)
database["tian"] = img_to_encoding("images/tian.jpg", FRmodel)
database["andrew"] = img_to_encoding("images/andrew.jpg", FRmodel)
database["kian"] = img_to_encoding("images/kian.jpg", FRmodel)
database["dan"] = img_to_encoding("images/dan.jpg", FRmodel)
database["sebastiano"] = img_to_encoding("images/sebastiano.jpg", FRmodel)
database["bertrand"] = img_to_encoding("images/bertrand.jpg", FRmodel)
database["kevin"] = img_to_encoding("images/kevin.jpg", FRmodel)
database["felix"] = img_to_encoding("images/felix.jpg", FRmodel)
database["benoit"] = img_to_encoding("images/benoit.jpg", FRmodel)
database["arnaud"] = img_to_encoding("images/arnaud.jpg", FRmodel)
# Out:
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)
# image.shape: (96, 96, 3)

# %%
def verify(image_path, identity, database, model):
    """
    Function that verifies if the person on the "image_path" image is "identity".
    
    Arguments:
    image_path -- path to an image
    identity -- string, name of the person you'd like to verify the identity. Has to be a resident of the Happy house.
    database -- python dictionary mapping names of allowed people's names (strings) to their encodings (vectors).
    model -- your Inception model instance in Keras
    
    Returns:
    dist -- distance between the image_path and the image of "identity" in the database.
    door_open -- True, if the door should open. False otherwise.
    """
    
    ### START CODE HERE ###
    
    # Step 1: Compute the encoding for the image. Use img_to_encoding() see example above. (≈ 1 line)
    encoding = img_to_encoding(image_path, model)
    
    # Step 2: Compute distance with identity's image (≈ 1 line)
#     dist = face_brain.compare_faces(encoding, database[identity])[0]
    dist = np.sqrt(np.sum(np.square(encoding - database[identity])))
    
    # Step 3: Open the door if dist < 0.7, else don't open (≈ 3 lines)
    if dist < 0.7:
        print("It's " + str(identity) + ", welcome home!")
        door_open = True
    else:
        print("It's not " + str(identity) + ", please go away")
        door_open = False
        
    ### END CODE HERE ###
        
    return dist, door_open

# %%
verify("images/camera_0.jpg", "younes", database, FRmodel)
# Out:
# image.shape: (96, 96, 3)
# It's younes, welcome home!
# (0.56811726, True)

# %%
verify("images/camera_2.jpg", "kian", database, FRmodel)
# Out:
# image.shape: (96, 96, 3)
# It's not kian, please go away
# (1.105366, False)

# %%
import face_detector_adapter

# %%
import face_detector_adapter
from matplotlib import pylab as plt
import numpy as np
# %matplotlib inline

# %%
ls
# Out:
# LICENSE                       facenet_adapter.py
# Untitled.ipynb                house.jpg
# __pycache__/                  images/
# ao1.jpg                       pretrain_inception_resnet_v1/
# ao2.jpg                       tf1.jpeg
# ao3.jpg                       王俊凯1.jpeg
# ao4.jpg                       赵丽颖1.jpg
# face_brain.py                 赵丽颖2.jpg
# face_detector_adapter.py      赵丽颖3.jpg
# facenet/

# %%
tf = face_brain.read_image('./tf1.jpeg')
faces, boxes = face_brain.detect_faces(tf)
# Out:
# WARNING:tensorflow:From /Users/zhangshulin_work/Desktop/AI-Play/Git/Face_Recongnition_Demo/facenet/src/align/detect_face.py:210: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /Users/zhangshulin_work/Desktop/AI-Play/Git/Face_Recongnition_Demo/facenet/src/align/detect_face.py:212: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
plt.imshow(faces[1])

# %%
tf_encodes = face_brain.encode_faces(faces)
face_brain.compare_faces(tf_encodes[0], tf_encodes)
# Out:
# array([0.       , 0.8352683, 1.0224494], dtype=float32)

# %%
wang = face_brain.read_image('./王俊凯1.jpeg')
wang_face, _ = face_brain.detect_faces(wang)
wang_encode = face_brain.encode_faces(wang_face)
face_brain.compare_faces(wang_encode, tf_encodes)
# Out:
# array([1.0968395 , 0.7400689 , 0.63147396], dtype=float32)
